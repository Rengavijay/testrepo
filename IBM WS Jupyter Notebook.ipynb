# %% [markdown]
# # **My Jupyter Notebook on IBM Watson Studio**
# ------------------------------------------------------------------

# %% [markdown]
# ## **Vijay Rengasamy**
# ## **Data Scientist**
# ### _I am interested in data science because to explore the data and improve my organization skills for my future._

# %% [markdown]
# # **Print Hello World**
# ---------------------------------------

# %%
print("Hello World")
# Out:
# Hello World

# %% [markdown]
# - I'm a
# - Data
# - Scientist

# %% [markdown]
# | SR:No. | Name |
# | ---- | ---- |
# | 1 | `Vijay` |
# | 2 | Siva |

# %% [markdown]
# ![alt text](data:image/jpeg;base64,...)

# %% [markdown]
# ****

# %% [markdown]
# [click](https://www.google.com) here to open `google`.
